# %% [markdown]
# ## Create Random Values with Seed

# %%
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib import image
import data_ops as do
import custom_dataset as cds
import argparse
from configparser import ConfigParser
from tqdm import tqdm
from torchvision import transforms
from numpy import asarray

# parser = argparse.ArgumentParser()
# parser.add_argument('--config', type=str, default='../config/config.ini', help='which config file to use')
# parser.add_argument('--opt', type=str, default='train')

# opt = parser.parse_args()
# config_path = opt.config
# opt_type = opt.opt
config_path = '../config/config_densenet121_TTA.ini'   # will be deleted
opt_type = 'train'                       # will be deleted

config = ConfigParser()
config.read(config_path)

root_dir = config.get('model', 'root_dir')
data_dir = config.get('data', 'data_dir')

def pil_loader(path):
    # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
    with open(path, 'rb') as f:
        img = Image.open(f)
        return img.convert('RGB')

# image,patientID,metaphase,label,side
# pID1.005-K_11_0_.png,pID1,005,11,0
if opt_type == 'train':
    img_labels = pd.read_csv('../data/train_data.csv') # '../data/train_data.csv'
elif opt_type == 'test':
    img_labels = pd.read_csv('../data/test.csv')

tr_image = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Resize(224),
                    transforms.CenterCrop(224)])

l_all_images = []
arr_sum = np.array([0.0, 0.0, 0.0])
arr_mean = np.array([0.0, 0.0, 0.0])
arr_std = np.array([0.0, 0.0, 0.0])

count=0
for img_path in tqdm(img_labels['image']):
    img_path = f'{data_dir}{opt_type}/singles/{img_path}'
    img = pil_loader(img_path)
    img = tr_image(img)
#     img = asarray(img)
    #print(f'shape: {img.shape} ... type: {type(img)}')
    img=img.detach().cpu().numpy()
    #l_all_images.append(img)
    count+=1
    if count == 5:
        break

arr_all_images = np.array(l_all_images)

print(f'shape of arr_all_images: {arr_all_images.shape}')
print(f'..........arr_shape: {arr_all_images[0].shape}')
mean_images = np.mean(arr_all_images, axis=(0,2,3))
std_images = np.std(arr_all_images, axis=(0,2,3))
print(f'mean_images: {mean_images}')
print(f'std_images: {std_images}')
# Out:
# ---------------------------------------------------------------------------
# NoSectionError                            Traceback (most recent call last)
# <ipython-input-1-1db817dc750b> in <module>
#      24 config.read(config_path)
#      25
# ---> 26 root_dir = config.get('model', 'root_dir')
#      27 data_dir = config.get('data', 'data_dir')
#      28
#
# ~/opt/anaconda3/lib/python3.7/configparser.py in get(self, section, option, raw, vars, fallback)
#     778         """
#     779         try:
# --> 780             d = self._unify_values(section, vars)
#     781         except NoSectionError:
#     782             if fallback is _UNSET:
#
# ~/opt/anaconda3/lib/python3.7/configparser.py in _unify_values(self, section, vars)
#    1144         except KeyError:
#    1145             if section != self.default_section:
# -> 1146                 raise NoSectionError(section) from None
#    1147         # Update with the entry specific variables
#    1148         vardict = {}
#
# ...

# %%
arr_all_images
# Out:
# array([], dtype=float64)

# %%
import random
params = [1/4, 1/4, 1/4, 1/4]
sample = [random.gammavariate(a, 1) for a in params]
sample = [v / sum(sample) for v in sample]
sample

# %%
params = [1/4, 1/4, 1/4, 1/4]
xs = [random.betavariate(params[0], sum(params[1:]))]
for j in range(1, len(params) - 1):
    phi = random.betavariate(params[j], sum(params[j + 1 :]))
    xs.append((1 - sum(xs)) * phi)
xs.append(1 - sum(xs))

# %%
tst=np.array([[0.1], [0.0], [0.7], [0.2]])
tst.shape
tst.reshape(4,)

# %%
x = {}
x[0] = np.zeros((10,1))
X=['t', 'u', 'r', 'i', 'a', 's', 'a', 'u', 'r', 'u', 's']
x[0][1]=1
x[0]

# %%
# range(10, p=[0,1])

# %%
for i in range(5):    
    rand_seed = np.random.randint(200)
    if rand_seed not in l_seed:
        l_seed.append(rand_seed)
l_seed

# %% [markdown]
# ## Check Model Info

# %%
import torch
from torchvision import models
from torch.distributions import normal

# %%
model_wu = models.densenet121(pretrained=False) # model_WeightUpdate # 7.978.856
model_wu
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
# ...

# %%
# model_wu = models.densenet121(pretrained=False) # model_WeightUpdate #  1.248.424
#model_wu = models.resnet18(pretrained=False) # model_WeightUpdate #  1.248.424
model_wu = models.squeezenet1_0(pretrained=False) # model_WeightUpdate #  1.248.424
# model_wu = models.alexnet(pretrained=False) # model_WeightUpdate     # 61.100.840
model_wu
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
def check_dropout(model):
    for m in model_wu.modules():
        if m.__class__.__name__.startswith('_DenseBlock'):   #_DenseBlock
            #print(m)
            m.drop_rate = 0.1
            
def check_dropout_generic(model):
    for m in model.modules():
        if m.__class__.__name__.startswith('Dropout'):
            m.drop_rate = 0.1
            print(m)
        
def enable_dropout_generic(model):
    for m in model.modules():
        if m.__class__.__name__.startswith('Dropout'):
            m.train()
            
def enable_dropout_Densenet(model, drop_rate = 0.1):
    for m in model.modules():
        if m.__class__.__name__.startswith('_DenseBlock'):
            m.drop_rate = drop_rate           
            
# model_wu.eval()
model_wu.train()
check_dropout_generic(model_wu)
#enable_dropout(model)
# Out:
# Dropout(p=0.5, inplace=False)
# Dropout(p=0.5, inplace=False)

# %%
from torch.nn import Module, Conv2d, ConvTranspose2d
import torch.nn as nn
def count_parameters(module: Module):
    """
    Counts the number of learnable parameters in a Module
    """
    return sum(p.numel() for p in module.parameters() if p.requires_grad)

def count_conv2d(module: Module):
    """
    Counts the number of convolutions and transposed convolutions in a Module
    """
    return len([m for m in module.modules() if isinstance(m, Conv2d) or isinstance(m, ConvTranspose2d)])

def count_linear(module: Module):
    """
    Counts the number of convolutions and transposed convolutions in a Module
    """
    return len([m for m in module.modules() if isinstance(m, nn.Linear)])


model_wu = models.densenet121(pretrained=False) # model_WeightUpdate #  1.248.424
print(f'densenet121..: # of conv_layers: {count_conv2d(model_wu)}\t\
      # of linear_layers: {count_linear(model_wu)}\t# of parameters: {count_parameters(model_wu)}')
model_wu = models.resnet18(pretrained=False) # model_WeightUpdate #  1.248.424
print(f'resnet18.....: # of conv_layers: {count_conv2d(model_wu)}\t\
      # of linear_layers: {count_linear(model_wu)}\t# of parameters: {count_parameters(model_wu)}')
model_wu = models.squeezenet1_0(pretrained=False) # model_WeightUpdate #  1.248.424
print(f'squeezenet1_0: # of conv_layers: {count_conv2d(model_wu)}\t\
      # of linear_layers: {count_linear(model_wu)}\t# of parameters: {count_parameters(model_wu)}')
model_wu = models.alexnet(pretrained=False) # model_WeightUpdate     # 61.100.840
print(f'alexnet......: # of conv_layers: {count_conv2d(model_wu)}\t\
      # of linear_layers: {count_linear(model_wu)}\t# of parameters: {count_parameters(model_wu)}')

# # number of parameters
# count_parameters(model_wu)

# # number of convolutions
# count_conv2d(model_wu)
# Out:
# densenet121..: # of conv_layers: 120	      # of linear_layers: 1	# of parameters: 7978856
# resnet18.....: # of conv_layers: 20	      # of linear_layers: 1	# of parameters: 11689512
# squeezenet1_0: # of conv_layers: 26	      # of linear_layers: 0	# of parameters: 1248424
# alexnet......: # of conv_layers: 5	      # of linear_layers: 3	# of parameters: 61100840

# %%
model_wu = models.alexnet(pretrained=False)
for m in model_wu.modules():    
    if isinstance(m, nn.Linear):
        print(m)
# Out:
# Linear(in_features=9216, out_features=4096, bias=True)
# Linear(in_features=4096, out_features=4096, bias=True)
# Linear(in_features=4096, out_features=1000, bias=True)

# %%
# model_wu = models.alexnet(pretrained=False)       # model_WeightUpdate  # 61.100.840  # Conv=5
# model_wu = models.squeezenet1_0(pretrained=False) # model_WeightUpdate  #  1.248.424  # Conv=26
# model_wu = models.resnet18(pretrained=False)      # model_WeightUpdate  # 11.689.512  # Conv=20
# model_wu = models.densenet121(pretrained=False)   # model_WeightUpdate  # 7.978.856   # Conv=120

# %%
count_parameters(model_wu)
# Out:
# 11689512

# %%
count_conv2d(model_wu)
# Out:
# 20

# %%
model_wu
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
# ...

# %%
df_model_meta = pd.read_csv(f'../models/model_meta_densenet121.csv')
df_model_meta
# Out:
#     model_name  model_weights                                       model_path
# 0  densenet121  densenet121_0  densenet121/densenet121_15epochs_0.9578.weights
# 1  densenet121  densenet121_1  densenet121/densenet121_11epochs_0.9569.weights
# 2  densenet121  densenet121_2  densenet121/densenet121_53epochs_0.9466.weights
# 3  densenet121  densenet121_3  densenet121/densenet121_11epochs_0.9571.weights
# 4  densenet121  densenet121_4  densenet121/densenet121_63epochs_0.9505.weights
# 5  densenet121  densenet121_5  densenet121/densenet121_11epochs_0.9576.weights
# 6  densenet121  densenet121_6  densenet121/densenet121_11epochs_0.9566.weights

# %%
df_model_meta = df_model_meta.drop([1,2,3,4,5,6], axis=0)
df_model_meta
# Out:
#     model_name  model_weights                                       model_path
# 0  densenet121  densenet121_0  densenet121/densenet121_15epochs_0.9578.weights

# %%
model_name_dropout = df_model_meta.loc[0, 'model_name']
for i in range(1, 50):
    df_model_meta.loc[i] = [model_name_dropout, f'{model_name_dropout}_{i}', df_model_meta.loc[0, 'model_path']]

# %%
df_model_meta.loc[0, 'model_name']
# Out:
# 'densenet121'

# %%
df_model_meta
# Out:
#      model_name   model_weights  \
# 0   densenet121   densenet121_0
# 1   densenet121   densenet121_1
# 2   densenet121   densenet121_2
# 3   densenet121   densenet121_3
# 4   densenet121   densenet121_4
# 5   densenet121   densenet121_5
# 6   densenet121   densenet121_6
# 7   densenet121   densenet121_7
# 8   densenet121   densenet121_8
# 9   densenet121   densenet121_9
# 10  densenet121  densenet121_10
# 11  densenet121  densenet121_11
# 12  densenet121  densenet121_12
# 13  densenet121  densenet121_13
# 14  densenet121  densenet121_14
# 15  densenet121  densenet121_15
# 16  densenet121  densenet121_16
# 17  densenet121  densenet121_17
# 18  densenet121  densenet121_18
# 19  densenet121  densenet121_19
# 20  densenet121  densenet121_20
# 21  densenet121  densenet121_21
# 22  densenet121  densenet121_22
# 23  densenet121  densenet121_23
# 24  densenet121  densenet121_24
# 25  densenet121  densenet121_25
# 26  densenet121  densenet121_26
# 27  densenet121  densenet121_27
# ...

# %%
model_wu.eval()
for m in model_wu.modules():
        if m.__class__.__name__.startswith('_DenseBlock'):   #_DenseBlock
            print(m.drop_rate)
            #m.drop_rate = 0.1
# Out:
# 0.1
# 0.1
# 0.1
# 0.1

# %%
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib import image
import data_ops as do
import custom_dataset as cds
import argparse
from configparser import ConfigParser
from tqdm import tqdm
from torchvision import transforms
from numpy import asarray
import torch

# parser = argparse.ArgumentParser()
# parser.add_argument('--config', type=str, default='../config/config.ini', help='which config file to use')
# parser.add_argument('--opt', type=str, default='train')

# opt = parser.parse_args()
# config_path = opt.config
# opt_type = opt.opt
config_path = '../config/config_x.ini'   # will be deleted
opt_type = 'train'                       # will be deleted

config = ConfigParser()
config.read(config_path)

root_dir = config.get('model', 'root_dir')
data_dir = config.get('data', 'data_dir')

def pil_loader(path):
    # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
    with open(path, 'rb') as f:
        img = Image.open(f)
        return img.convert('RGB')

# image,patientID,metaphase,label,side
# pID1.005-K_11_0_.png,pID1,005,11,0
if opt_type == 'train':
    img_labels = pd.read_csv('../data/train_data.csv') # '../data/train_data.csv'
elif opt_type == 'test':
    img_labels = pd.read_csv('../data/test.csv')

tr_image = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Resize(224),
                    transforms.CenterCrop(224)])

l_all_images = []
arr_sum = np.array([0.0, 0.0, 0.0])
arr_mean = np.array([0.0, 0.0, 0.0])
arr_std = np.array([0.0, 0.0, 0.0])

psum    = torch.tensor([0.0, 0.0, 0.0])
psum_sq = torch.tensor([0.0, 0.0, 0.0])

count=0
for img_path in tqdm(img_labels['image']):
    img_path = f'{data_dir}{opt_type}/singles/{img_path}'
    img = pil_loader(img_path)
    img = tr_image(img)
#     img = asarray(img)
    #print(f'shape: {img.shape} ... type: {type(img)}')
    psum    += img.sum(axis        = [1, 2])/224/224
    psum_sq += (img ** 2).sum(axis = [1, 2])/224/224
    #l_all_images.append(img)
    count+=1
    if count == 5:
        break

mean_images = psum / count
total_var  = (psum_sq / count) - (mean_images ** 2)
std_images  = torch.sqrt(total_var)
        
#arr_all_images = np.array(l_all_images)

#print(f'shape of arr_all_images: {arr_all_images.shape}')
#print(f'..........arr_shape: {arr_all_images[0].shape}')
#mean_images = np.mean(arr_all_images, axis=(0,2,3))
#std_images = np.std(arr_all_images, axis=(0,2,3))
print(f'mean_images: {mean_images}')
print(f'std_images: {std_images}')

# %%
np.sum(arr_all_images, axis=(0,2,3))/(224*224*5)

# %%
arr_sum = np.zeros((3,224,224))
arr_sum_square = np.zeros(3)
for arr in arr_all_images:
    arr_sum += arr

arr_mean = np.mean(arr_sum/5, axis=(1,2))
arr_mean
    
for arr in arr_all_images:
    arr_int = np.sum(arr, axis=(1,2)) - arr_mean
    arr_sum_square += np.power(arr_int, 2)

arr_std = arr_sum_square/5/224/224
arr_std = np.sqrt(arr_std)
arr_std

# %%
arr_sum = np.zeros((3,224,224))
arr_sum_square = np.zeros((3,224,224))
for arr in arr_all_images:
    arr_sum += arr

arr_mean = np.mean(arr_sum/5, axis=(1,2))
arr_mean
    
for arr in arr_all_images:
    arr_int = arr - arr_mean.reshape(1,3)
    arr_sum_square += np.power(arr_int, 2)

arr_std = np.sqrt(arr_sum_square/5)
arr_std

# %%
arr_mean

# %%
np.broadcast_to(arr_mean.reshape(3,1), (3, 224, 224))

# %%
n1=np.array([[1,2,3],[0,5,2]])
n2=np.array([[1,2,4],[0,0,0]])
n1+n2-[1,0,2]

# %%
n1+n2

# %%
np.mean(arr_sum, axis=(1,2))/5

# %%
shape of arr_all_images: (5, 3, 224, 224)
..........arr_shape: (3, 224, 224)
mean_images: [0.8175462 0.8175462 0.8175462]
std_images: [0.20942761 0.20942761 0.20942761]

# %%
arr_all_images.shape

# %%
import torch
import numpy as np

torch.manual_seed(10)
np.random.seed(10)

print(torch.randn(2, 2, 2))
print(np.random.randint(0,22))

# %%
l_xx=np.random.randint(5, size=(2, 4, 3))
l_xx

# %%
np.mean(l_xx, axis=2)

# %%
l_x1 = np.array([[1,2,1],[2,1,3, 4],[3,4,3]])
l_x2 = np.array([[3,2,1],[4,3,5],[1,2,5]])

l_x = (l_x1 + l_x2)/2
l_xx = np.array([l_x1, l_x2])
np.mean(l_xx, axis=0)

# %%
shape=[4,4,3]
shape2=[4,5,3]
l_x=[]
arr1=np.random.randint(low=1, high=4, size=shape)
l_x.append(arr1)
arr2=np.random.randint(low=1, high=4, size=shape2)
l_x.append(arr2)
#arr_merge = np.array([arr1, arr2])
arr_merge = np.array(l_x)

# %%
l_x

# %%
arr_merge.shape

# %%
arr2

# %%
np.mean(arr_merge, axis=(0,1,2))

# %%
l_x1.shape

# %%
from configparser import ConfigParser

config = ConfigParser()
#config.read('../config/config.ini')
config_path = '../config/config.ini'
config.read(config_path)

for section in config.sections():
    print(f'>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> section: {section}')
    for (key, val) in config.items(section):
        print(f'{key}: {val}')

# %% [markdown]
# ## Plot CLR

# %%
import matplotlib.pyplot as plt
l_LR = []
model = torch.nn.Linear(2, 1)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=0.01, max_lr=0.1,step_size_up=10,mode='triangular')
for epoch in range(10):
     for batch in range(10):
        optimizer.step()
        scheduler.step()
        l_LR.append(scheduler.get_last_lr())
        
plt.plot(l_LR)

# %%
import logging

# %%
x='info'
#dict_log_level = [('error', logging.ERROR), ('info': logging.INFO), ('debug': logging.DEBUG)]
dict_log_level = {'error': logging.ERROR, 'info': logging.INFO, 'debug': logging.DEBUG}
dict_log_level['error']

# %%
#!pip3 install pickle5
import pickle5 as pickle
#import pickle
with open('../results/resnet18_28.04.2021_20.39.44__LR.pkl', 'rb') as fp:
     l_LR = pickle.load(fp)

plt.plot(l_LR)

# %%
with open('../results/resnet18_29.04.2021_00.46.49_df_result_ensemble.pkl', 'rb') as fp:
     df_result_ensemble = pickle.load(fp)

df_result_ensemble

# %%
import pandas as pd
class_to_idx = {}
class_to_idx[1] = 0
class_to_idx[2] = 1
df_x = pd.DataFrame(class_to_idx, index=[0])
df_xt=df_x.transpose()
df_xt

# %%
import pandas as pd

l_index = [0, 1]
l_label = [1, 'x']
class_to_idx = {'label': l_label, 'index': l_index}
df_x = pd.DataFrame(class_to_idx)
df_x

# %%
df_x[df_x['label']==2]['index']

# %%
df_l=df_x.set_index('index')
df_i=df_x.set_index('label')

# %%
arr = os.listdir('../models/squeezenet1_0')
l_files = ''
for i, file in enumerate(arr):
    f_input = f'squeezenet1_0,squeezenet1_{i},dir_squeezenet1_0/{file}\n'
    l_files+=f_input
print(l_files)

# %%
#def data_loader_predict(data_dir, input_shape, name = 'x'):    
def data_loader_predict(image_datasets, input_shape, name = 'x'):    
    scale = 256
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    
    if name == "bninception":
        val = transforms.Compose([transforms.Scale(scale),
                              transforms.TenCrop(input_shape),
                              transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
                              transforms.Lambda(lambda bgr: torch.stack([ToSpaceBGR(True)(bgrformat) for bgrformat in bgr])),
                              transforms.Lambda(lambda range255: torch.stack([ToRange255(True)(ranges) for ranges in range255])),
                              transforms.Lambda(lambda normal: torch.stack([transforms.Normalize(mean, std)(normalize) for normalize in normal]))])
    else:
        val = transforms.Compose([transforms.Scale(scale),
                              transforms.TenCrop(input_shape),
                              transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
                              transforms.Lambda(lambda normal: torch.stack([transforms.Normalize(mean, std)(normalize) for normalize in normal]))])
    #image_datasets = datasets.ImageFolder(data_dir, val)
    dataloaders = torch.utils.data.DataLoader(image_datasets, batch_size=1,
                                         shuffle=False, num_workers=1)
    return dataloaders, image_datasets

# %%
df_train_data = pd.read_csv('../data/train_data.csv')
df_train_data
# Out:
#                                    image          patientID  metaphase label  \
# 0      MA160865191500026.005-K_11_0_.png  MA160865191500026          5    11
# 1      MA160865191500038.002-K_11_1_.png  MA160865191500038          2    11
# 2      MA160865191500048.021-K_11_1_.png  MA160865191500048         21    11
# 3      MA160865191500044.006-K_11_0_.png  MA160865191500044          6    11
# 4      MA160865191500030.011-K_11_0_.png  MA160865191500030         11    11
# ...                                  ...                ...        ...   ...
# 38159   MA160814197500031.072-K_2_0_.png  MA160814197500031         72     2
# 38160   MA160814197500027.074-K_2_1_.png  MA160814197500027         74     2
# 38161   MA160865191500032.002-K_2_0_.png  MA160865191500032          2     2
# 38162   MA160873676300037.006-K_2_1_.png  MA160873676300037          6     2
# 38163   MA160814197500023.137-K_2_1_.png  MA160814197500023        137     2
#
#        side
# 0         0
# 1         1
# ...

# %%
import os, shutil
from tqdm import tqdm
from os import listdir
#from os.path import isfile, join

target_dir = '/Users/melih/Documents/Masters/KTH_DASE-ICT Innovation_Data Science/___Master Thesis/\
PyTorch_Exercise/BioImLab/data/BioImLab_single_chromosomes_05.04.2021/test/singles_t/'

func = shutil.copy('', '')

source_dir = f'/Users/melih/Documents/Masters/KTH_DASE-ICT Innovation_Data Science/___Master Thesis/\
PyTorch_Exercise/BioImLab/data/BioImLab_single_chromosomes_05.04.2021/test_old/24/'

files = os.listdir(source_dir)
for f in tqdm(files):
    src = source_dir + f
    dst = target_dir + f
    func(src, dst)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-100-8814d20a0146> in <module>
#       7 PyTorch_Exercise/BioImLab/data/BioImLab_single_chromosomes_05.04.2021/test/singles_t/'
#       8
# ----> 9 func = shutil.copy('', '')
#      10
#      11 source_dir = f'/Users/melih/Documents/Masters/KTH_DASE-ICT Innovation_Data Science/___Master Thesis/\
#
# ~/opt/anaconda3/lib/python3.7/shutil.py in copy(src, dst, follow_symlinks)
#     246     if os.path.isdir(dst):
#     247         dst = os.path.join(dst, os.path.basename(src))
# --> 248     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     249     copymode(src, dst, follow_symlinks=follow_symlinks)
#     250     return dst
#
# ~/opt/anaconda3/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# ...

# %%
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
import matplotlib.pyplot as plt
# creating the dataset
lst_models = ['Alexnet_E10', 'Single-Resnet18', 'Squeezenet1_0_E12', 'Single-Densenet121', 
              'Densenet121_Snap7', 'Resnet18_E9', 'Densenet121_E5', 'Densenet121_E7']
lst_acc = [96.3851 , 96.4215, 96.7787, 96.8151, 96.8297, 96.8661, 96.9827, 97.092]
  
fig = plt.figure(figsize = (15, 5))
 
# creating the bar plot
#plt.bar(lst_models, lst_acc, color ='maroon', width = 0.4)
plt.plot(lst_models, lst_acc)
 
plt.xlabel("Model")
plt.ylabel("Accuracy")
#plt.title("Students enrolled in different courses")
plt.show()

# %%
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
import matplotlib.pyplot as plt
# creating the dataset
lst_models = ['Alexnet_E10', 'Single-Resnet18', 'Squeezenet1_0_E12', 'Single-Densenet121', 
              'Densenet121_Snap7', 'Resnet18_E9', 'Densenet121_E5', 'Densenet121_E7']
lst_acc = [96.3851 , 96.4215, 96.7787, 96.8151, 96.8297, 96.8661, 96.9827, 97.092]
  
fig = plt.figure(figsize = (15, 5))
 
# creating the bar plot
plt.bar(lst_models, lst_acc, color ='maroon', width = 0.4)
#plt.plot(lst_models, lst_acc)
 
plt.xlabel("Model")
plt.ylabel("Accuracy")
#plt.title("Students enrolled in different courses")
plt.show()

# %%
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
import matplotlib.pyplot as plt
# creating the dataset
lst_models = ['Alexnet_E10', 'Single-Resnet18', 'Squeezenet1_0_E12', 'Single-Densenet121', 
              'Densenet121_Snap7', 'Resnet18_E9', 'Densenet121_E5', 'mix', 'Densenet121_E7']
lst_acc = [96.3851 , 96.4215, 96.7787, 96.8151, 96.8297, 96.8661, 96.9827, 97.041, 97.092]
lst_Work_Load_P = [5.735734, 5.050652, 3.884557, 4.044895, 4.205233, 4.052183, 3.833540, 3.673202, 3.622185]
lst_Work_Load_N = [787, 693, 533, 555, 577, 556, 526, 497]
lst_Tolerance_Range = [11, 20, 25, 32, 24, 28, 38, 33, 33]
  
fig = plt.figure(figsize = (18, 5))
 
# creating the bar plot
plt.bar(lst_models, lst_Work_Load_P, color ='skyblue', width = 0.4)
#plt.bar(lst_models, lst_acc, color ='maroon', width = 0.4)
#plt.plot(lst_models, lst_Work_Load_P)
#plt.plot(lst_models, lst_Work_Load_P)
 
plt.xlabel("Model")
plt.ylabel("Work_Load_P")
#plt.title("Students enrolled in different courses")
plt.show()

# %%
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
import matplotlib.pyplot as plt
# creating the dataset
# lst_models = ['Alexnet_E10', 'Single-Resnet18', 'Squeezenet1_0_E12', 'Single-Densenet121', 
#               'Densenet121_Snap7', 'Resnet18_E9', 'Densenet121_E5', 'Densenet121_E7']
# lst_acc = [96.3851 , 96.4215, 96.7787, 96.8151, 96.8297, 96.8661, 96.9827, 97.092]
# lst_Tolerance_Range = [11, 20, 25, 32, 24, 28, 38, 33]
  
fig = plt.figure(figsize = (18, 5))
 
# creating the bar plot
#plt.bar(lst_models, lst_Work_Load_N, color ='maroon', width = 0.4)
plt.plot(lst_models, lst_Tolerance_Range)
 
plt.xlabel("Model")
plt.ylabel("Tolerance_Range")
#plt.title("Students enrolled in different courses")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

width = .35 # width of a bar

m1_t = pd.DataFrame({
 'abnormal' : [90,40,30,30,30,25,25,20,15,10],
 'fix' : [60,70,65,70,70,60,50,45,45,45],
 'normal' : [140,160,170,180,190,200,210,220,230,240],
 'bad_rate' : [210,100,100,70,70,75,70,60,65,60]})

m1_t[['abnormal','fix','normal']].plot(kind='bar', width = width)
m1_t['bad_rate'].plot(secondary_y=True)

ax = plt.gca()
plt.xlim([-width, len(m1_t['normal'])-width])
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10'))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#width = .35 # width of a bar

m1_t = pd.DataFrame({
 #'lst_Tolerance_Range' : lst_Tolerance_Range,
 'lst_Work_Load_P' : lst_Work_Load_P,
 'lst_acc' : lst_acc})

m1_t[['lst_acc']].plot(kind='bar', width = width)
#m1_t['lst_Tolerance_Range'].plot(secondary_y=True)
m1_t['lst_Work_Load_P'].plot(secondary_y=True)

#m1_t[['lst_Tolerance_Range']].plot(kind='bar', width = width)
# m1_t[['lst_Tolerance_Range']].plot(kind='bar')
# m1_t['lst_acc'].plot(secondary_y=True)

ax = plt.gca()
plt.xlim([-width, len(m1_t['lst_acc'])-width])
# plt.xlim([-width, 100])
ax.set_xticklabels(['Alexnet_E10', 'Single-Resnet18', 'Squeezenet1_0_E12', 'Single-Densenet121', 
              'Densenet121_Snap7', 'Resnet18_E9', 'Densenet121_E5', 'Densenet121_E7'])
plt.width = 1000
plt.show()

# %%
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
import matplotlib.pyplot as plt
# creating the dataset
lst_models = ['Densenet121_TTA1_Single', 'Densenet121_Drpout20 ', 'Densenet121_E6', 'Densenet121_TTA32_Single', 
              'Densenet121_TTA32_E6']
lst_acc = [96.4798, 96.7787, 97.1795, 97.2305, 97.2597]
lst_Work_Load_P = [5.218279, 4.402012, 3.418118, 3.316085, 3.163035]
lst_Work_Load_N = [716, 604, 469, 455, 434]
lst_Tolerance_Range = [23, 34, 44, 42, 47]
  
fig = plt.figure(figsize = (15, 5))
 
# creating the bar plot
plt.bar(lst_models, lst_Work_Load_P, color ='skyblue', width = 0.4)
#plt.bar(lst_models, lst_Tolerance_Range, color ='skyblue', width = 0.4)
#plt.plot(lst_models, lst_Work_Load_P)
#plt.plot(lst_models, lst_Work_Load_P)
 
plt.xlabel("Model")
plt.ylabel("Work_Load_P")
#plt.title("Students enrolled in different courses")
plt.show()

# %%
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
import matplotlib.pyplot as plt
# creating the dataset
# lst_models = ['Densenet121_TTA1_Single', 'Densenet121_TTA1_E6', 'Densenet121_TTA32_Single', 
#               'Densenet121_TTA32_E6']
# lst_acc = [96.4798, 97.1795, 97.2305, 97.2597]
# lst_Work_Load_P = [5.218279, 3.418118, 3.316085, 3.163035]
# lst_Work_Load_N = [716, 469, 455, 434]
# lst_Tolerance_Range = [23, 44, 42, 47]
  
fig = plt.figure(figsize = (15, 5))
 
# creating the bar plot
#plt.bar(lst_models, lst_Work_Load_P, color ='maroon', width = 0.4)
#plt.bar(lst_models, lst_Tolerance_Range, color ='skyblue', width = 0.4)
plt.plot(lst_models, lst_Work_Load_P)
#plt.plot(lst_models, lst_Work_Load_P)
 
plt.xlabel("Model")
plt.ylabel("Tolerance_Range")
#plt.title("Students enrolled in different courses")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#width = .35 # width of a bar

m1_t = pd.DataFrame({
 #'lst_Tolerance_Range' : lst_Tolerance_Range,
 'lst_Work_Load_P' : lst_Work_Load_P,
 'lst_acc' : lst_acc})

m1_t[['lst_acc']].plot(kind='bar', width = width)
#m1_t['lst_Tolerance_Range'].plot(secondary_y=True)
m1_t['lst_Work_Load_P'].plot(secondary_y=True)

#m1_t[['lst_Tolerance_Range']].plot(kind='bar', width = width)
# m1_t[['lst_Tolerance_Range']].plot(kind='bar')
# m1_t['lst_acc'].plot(secondary_y=True)

ax = plt.gca()
plt.xlim([-width, len(m1_t['lst_acc'])-width])
# plt.xlim([-width, 100])
ax.set_xticklabels(['Alexnet_E10', 'Single-Resnet18', 'Squeezenet1_0_E12', 'Single-Densenet121', 
              'Densenet121_Snap7', 'Resnet18_E9', 'Densenet121_E5', 'Densenet121_E7'])
plt.width = 1000
plt.show()
